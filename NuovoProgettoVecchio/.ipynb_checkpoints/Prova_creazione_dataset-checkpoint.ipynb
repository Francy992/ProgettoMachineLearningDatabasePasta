# %%
#Variabilil globali
width = 512
height = 512

# %%
from AlexNet import *
from torch.utils.data.dataset import Dataset
from PIL import Image
from os import path
from torchvision import transforms
import numpy as np
import torch
from torch.utils.data import DataLoader

np.random.seed(1234)
torch.random.manual_seed(1234);

class ScenesDataset(Dataset):
    def __init__(self,base_path,txt_list,transform=None):
        #conserviamo il path alla cartella contenente le immagini
        self.base_path=base_path
        #carichiamo la lista dei file
        #sarà una matrice con n righe (numero di immagini) e 2 colonne (path, etichetta)
        self.images = np.loadtxt(txt_list,dtype=str,delimiter=',')
        #print("self.images ha i seguenti elementi:", len(self.images))
        #conserviamo il riferimento alla trasformazione da applicare
        self.transform = transform
    def __getitem__(self, index):
        #print("Get item numero -->", index)
        #recuperiamo il path dell'immagine di indice index e la relativa etichetta
        f,c = self.images[index]
        #carichiamo l'immagine utilizzando PIL e facciamo il resize a 3 canali.
        im = Image.open(path.join(self.base_path, f)).convert("RGB")
        
        #Resize:
        im = im.resize((width,height))
        #se la trasfromazione è definita, applichiamola all'immagine
        if self.transform is not None:
            im = self.transform(im)
        
        
        #convertiamo l'etichetta in un intero
        label = int(c)
        #restituiamo un dizionario contenente immagine etichetta
        return {'image' : im, 'label':label}
    #restituisce il numero di campioni: la lunghezza della lista "images"
    def __len__(self):
        #print("Ho invocato len, vale-->", len(self.images))
        return len(self.images)

# %%
dataset = ScenesDataset('Dataset','train.txt',transform=transforms.ToTensor())
for i in range(0, len(dataset)):
    print(dataset[i]['image'].shape, dataset[i]['label'])
# Out:
# torch.Size([3, 512, 512]) 0
# torch.Size([3, 512, 512]) 0
# torch.Size([3, 512, 512]) 1
# torch.Size([3, 512, 512]) 1
# torch.Size([3, 512, 512]) 2
# torch.Size([3, 512, 512]) 2

# %%
#Normalizziamo i dati:
#dataset = ScenesDataset('8scenes','8scenes/train.txt',transform=transforms.ToTensor())
m = np.zeros(3)
for sample in dataset:
    m+= np.array(sample['image'].sum(1).sum(1)) #accumuliamo la somma dei pixel canale per canale
#dividiamo per il numero di immagini moltiplicato per il numero di pixel
m=m/(len(dataset)*width*height)
#procedura simile per calcolare la deviazione standard
s = np.zeros(3)
for sample in dataset:
    s+= np.array(((sample['image']-torch.Tensor(m).view(3,1,1))**2).sum(1).sum(1))
s=np.sqrt(s/(len(dataset)*width*height))

# %%
print("Medie",m)
print("Dev.Std.",s)
# Out:
# Medie [0.83033568 0.70723725 0.52163703]
# Dev.Std. [0.12735092 0.22173076 0.26922328]

# %%
transformss = transforms.Compose([transforms.ToTensor(), transforms.Normalize(m,s)])

mnist_train = ScenesDataset('Dataset','train.txt',transform=transformss)
mnist_test = ScenesDataset('Dataset','test.txt',transform=transformss)
print()
mnist_train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=4, num_workers=0, shuffle=True)
mnist_test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=4, num_workers=0)
print(mnist_train)
# Out:
# <__main__.ScenesDataset object at 0x000001598788BBE0>

# %%
from torch import nn
class LeNetColor(nn.Module):
    def __init__(self):
        super(LeNetColor, self).__init__()
        #ridefiniamo il modello utilizzando i moduli sequential.
        #ne definiamo due: un "feature extractor", che estrae le feature maps
        #e un "classificatore" che implementa i livelly FC
        self.feature_extractor = nn.Sequential(
        nn.Conv2d(3, 18, 5), #Input: 3 x 32 x 32. Ouput: 18 x 28 x 28
        nn.MaxPool2d(2), #Input: 18 x 28 x 28. Output: 18 x 14 x 14
        nn.ReLU(),
        nn.Conv2d(18, 28, 5), #Input 18 x 14 x 14. Output: 28 x 10 x 10
        nn.MaxPool2d(2), #Input 28 x 10 x 10. Output: 28 x 5 x 5
        nn.ReLU()
        )
        self.classifier = nn.Sequential(
        nn.Linear(700, 360), #Input: 28 * 5 * 5
        nn.ReLU(),
        nn.Linear(360, 252),
        nn.ReLU(),
        nn.Linear(252, 100)
        )
    def forward(self,x):
        #Applichiamo le diverse trasformazioni in cascata
        x = self.feature_extractor(x)
        x = self.classifier(x.view(x.shape[0],-1))
        return x

# %%
net = AlexNet()
sum([p.numel() for p in net.parameters()])
# Out:
# 57016131

# %%
from sklearn.metrics import accuracy_score
from torch.optim import SGD
from torch.autograd import Variable
def train_classification(model, lr=0.01, epochs=20, momentum=0.9, \
    train_loader=mnist_train_loader, test_loader=mnist_test_loader):
    criterion = nn.CrossEntropyLoss()
    optimizer = SGD(model.parameters(),lr, momentum=momentum)
    loaders = {'train':train_loader, 'test':test_loader}
    losses = {'train':[], 'test':[]}
    accuracies = {'train':[], 'test':[]}
    if torch.cuda.is_available():
        model=model.cuda()
    for e in range(epochs):
        #print("Primo ciclo for.")
        for mode in ['train', 'test']:
            #print("Secondo ciclo for.")
            if mode=='train':
                model.train()
            else:
                model.eval()
            epoch_loss = 0
            epoch_acc = 0
            samples = 0
            #print("Mode-->",mode)
            #print("Enumerate-->", loaders[mode])
            for i, batch in enumerate(loaders[mode]):
                #trasformiamo i tensori in variabili
                x=Variable(batch['image'], requires_grad=(mode=='train'))
                y=Variable(batch['label'])
                if torch.cuda.is_available():
                    x, y = x.cuda(), y.cuda()
                    print("Con cuda")
                #else:
                    #print("Senza cuda")
                output = model(x)
                #print(type(output))
                #print(output)
                l = criterion(output,y)
                if mode=='train':
                    l.backward()
                    optimizer.step()
                    optimizer.zero_grad()
                #print("L-->",l.item())
                acc = accuracy_score(y.cpu().data,output.cpu().max(1)[1].data)
                epoch_loss+=l.data.item()*x.shape[0]
                epoch_acc+=acc*x.shape[0]
                samples+=x.shape[0]
                #print ("\r[%s] Epoch %d/%d. Iteration %d/%d. Loss: %0.2f. Accuracy: %0.2f\t\t\t\t\t" % \
                (mode, e+1, epochs, i, len(loaders[mode]), epoch_loss/samples, epoch_acc/samples),
                epoch_loss/samples,
                epoch_acc/samples,
                losses[mode].append(epoch_loss))
                accuracies[mode].append(epoch_acc)
            #print("Fine secondo ciclo for")
        print("\r[%s] Epoch %d/%d. Iteration %d/%d. Loss: %0.2f. Accuracy: %0.2f\t\t\t\t\t" % \
        (mode, e+1, epochs, i, len(loaders[mode]), epoch_loss, epoch_acc))

    print("Ho finito.")
    #restituiamo il modello e i vari log
    return model, (losses, accuracies)

# %%
lenet_mnist, lenet_mnist_logs = train_classification(net, epochs=200)
# Out:
# Con cuda
# [train] Epoch 1/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.0974090099334717 0.25 None
# Con cuda
# [train] Epoch 1/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.17					 1.1002230644226074 0.16666666666666666 None
# Con cuda
# [test] Epoch 1/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0982264280319214 0.3333333333333333 None
# [test] Epoch 1/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 2/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.0982332229614258 0.25 None
# Con cuda
# [train] Epoch 2/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.098310947418213 0.3333333333333333 None
# Con cuda
# [test] Epoch 2/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0979162454605103 0.3333333333333333 None
# [test] Epoch 2/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 3/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.0985517501831055 0.25 None
# Con cuda
# [train] Epoch 3/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0982624689737956 0.3333333333333333 None
# Con cuda
# [test] Epoch 3/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0975309610366821 0.3333333333333333 None
# [test] Epoch 3/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 4/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.0988054275512695 0.25 None
# Con cuda
# [train] Epoch 4/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0973949432373047 0.3333333333333333 None
# Con cuda
# [test] Epoch 4/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0972460508346558 0.3333333333333333 None
# [test] Epoch 4/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 5/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.100752592086792 0.25 None
# Con cuda
# [train] Epoch 5/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0994569460550945 0.3333333333333333 None
# Con cuda
# [test] Epoch 5/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0969834327697754 0.3333333333333333 None
# [test] Epoch 5/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 6/30. Iteration 0/2. Loss: 1.08. Accuracy: 0.50					 1.0836853981018066 0.5 None
# Con cuda
# [train] Epoch 6/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.097279707590739 0.3333333333333333 None
# Con cuda
# [test] Epoch 6/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0967624187469482 0.3333333333333333 None
# [test] Epoch 6/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 7/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.1014988422393799 0.25 None
# Con cuda
# [train] Epoch 7/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0969899495442708 0.3333333333333333 None
# Con cuda
# [test] Epoch 7/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0963616371154785 0.3333333333333333 None
# [test] Epoch 7/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 8/30. Iteration 0/2. Loss: 1.10. Accuracy: 0.25					 1.104194164276123 0.25 None
# Con cuda
# [train] Epoch 8/30. Iteration 1/2. Loss: 1.09. Accuracy: 0.33					 1.0931889216105144 0.3333333333333333 None
# Con cuda
# [test] Epoch 8/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0959149599075317 0.3333333333333333 None
# [test] Epoch 8/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 9/30. Iteration 0/2. Loss: 1.07. Accuracy: 0.50					 1.0687060356140137 0.5 None
# Con cuda
# [train] Epoch 9/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0969408353169758 0.3333333333333333 None
# Con cuda
# [test] Epoch 9/30. Iteration 0/1. Loss: 1.10. Accuracy: 0.33					 1.0953606367111206 0.3333333333333333 None
# [test] Epoch 9/30. Iteration 0/1. Loss: 3.29. Accuracy: 1.00
# Con cuda
# [train] Epoch 10/30. Iteration 0/2. Loss: 1.11. Accuracy: 0.25					 1.1097019910812378 0.25 None
# Con cuda
# [train] Epoch 10/30. Iteration 1/2. Loss: 1.09. Accuracy: 0.33					 1.0907679398854573 0.3333333333333333 None
# Con cuda
# [test] Epoch 10/30. Iteration 0/1. Loss: 1.09. Accuracy: 0.33					 1.0940141677856445 0.3333333333333333 None
# [test] Epoch 10/30. Iteration 0/1. Loss: 3.28. Accuracy: 1.00
# Con cuda
# [train] Epoch 11/30. Iteration 0/2. Loss: 1.08. Accuracy: 0.50					 1.0838372707366943 0.5 None
# Con cuda
# [train] Epoch 11/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0950879255930583 0.3333333333333333 None
# Con cuda
# [test] Epoch 11/30. Iteration 0/1. Loss: 1.09. Accuracy: 0.33					 1.0922918319702148 0.3333333333333333 None
# [test] Epoch 11/30. Iteration 0/1. Loss: 3.28. Accuracy: 1.00
# Con cuda
# [train] Epoch 12/30. Iteration 0/2. Loss: 1.09. Accuracy: 0.50					 1.0884907245635986 0.5 None
# Con cuda
# [train] Epoch 12/30. Iteration 1/2. Loss: 1.09. Accuracy: 0.33					 1.093237082163493 0.3333333333333333 None
# Con cuda
# [test] Epoch 12/30. Iteration 0/1. Loss: 1.09. Accuracy: 0.33					 1.0899876356124878 0.3333333333333333 None
# [test] Epoch 12/30. Iteration 0/1. Loss: 3.27. Accuracy: 1.00
# Con cuda
# [train] Epoch 13/30. Iteration 0/2. Loss: 1.07. Accuracy: 0.50					 1.0733414888381958 0.5 None
# Con cuda
# [train] Epoch 13/30. Iteration 1/2. Loss: 1.08. Accuracy: 0.50					 1.0834660530090332 0.5 None
# Con cuda
# [test] Epoch 13/30. Iteration 0/1. Loss: 1.09. Accuracy: 0.33					 1.0879027843475342 0.3333333333333333 None
# [test] Epoch 13/30. Iteration 0/1. Loss: 3.26. Accuracy: 1.00
# Con cuda
# [train] Epoch 14/30. Iteration 0/2. Loss: 1.11. Accuracy: 0.00					 1.1126518249511719 0.0 None
# Con cuda
# [train] Epoch 14/30. Iteration 1/2. Loss: 1.08. Accuracy: 0.33					 1.079088608423869 0.3333333333333333 None
# Con cuda
# [test] Epoch 14/30. Iteration 0/1. Loss: 1.09. Accuracy: 0.33					 1.0853095054626465 0.3333333333333333 None
# [test] Epoch 14/30. Iteration 0/1. Loss: 3.26. Accuracy: 1.00
# Con cuda
# [train] Epoch 15/30. Iteration 0/2. Loss: 1.07. Accuracy: 0.25					 1.0706992149353027 0.25 None
# Con cuda
# [train] Epoch 15/30. Iteration 1/2. Loss: 1.06. Accuracy: 0.33					 1.0632941722869873 0.3333333333333333 None
# Con cuda
# [test] Epoch 15/30. Iteration 0/1. Loss: 1.08. Accuracy: 0.33					 1.0837891101837158 0.3333333333333333 None
# [test] Epoch 15/30. Iteration 0/1. Loss: 3.25. Accuracy: 1.00
# Con cuda
# [train] Epoch 16/30. Iteration 0/2. Loss: 1.03. Accuracy: 0.50					 1.026648998260498 0.5 None
# Con cuda
# [train] Epoch 16/30. Iteration 1/2. Loss: 1.09. Accuracy: 0.33					 1.0931158860524495 0.3333333333333333 None
# Con cuda
# [test] Epoch 16/30. Iteration 0/1. Loss: 1.08. Accuracy: 0.33					 1.0825780630111694 0.3333333333333333 None
# [test] Epoch 16/30. Iteration 0/1. Loss: 3.25. Accuracy: 1.00
# Con cuda
# [train] Epoch 17/30. Iteration 0/2. Loss: 1.13. Accuracy: 0.25					 1.132144570350647 0.25 None
# Con cuda
# [train] Epoch 17/30. Iteration 1/2. Loss: 1.10. Accuracy: 0.33					 1.0964512427647908 0.3333333333333333 None
# Con cuda
# [test] Epoch 17/30. Iteration 0/1. Loss: 1.07. Accuracy: 0.67					 1.0690377950668335 0.6666666666666666 None
# [test] Epoch 17/30. Iteration 0/1. Loss: 3.21. Accuracy: 2.00
# Con cuda
# [train] Epoch 18/30. Iteration 0/2. Loss: 1.13. Accuracy: 0.25					 1.125449299812317 0.25 None
# Con cuda
# [train] Epoch 18/30. Iteration 1/2. Loss: 1.07. Accuracy: 0.33					 1.0692245562871296 0.3333333333333333 None
# Con cuda
# [test] Epoch 18/30. Iteration 0/1. Loss: 1.04. Accuracy: 0.67					 1.0443196296691895 0.6666666666666666 None
# [test] Epoch 18/30. Iteration 0/1. Loss: 3.13. Accuracy: 2.00
# Con cuda
# [train] Epoch 19/30. Iteration 0/2. Loss: 1.01. Accuracy: 0.75					 1.0120024681091309 0.75 None
# Con cuda
# [train] Epoch 19/30. Iteration 1/2. Loss: 1.02. Accuracy: 0.67					 1.0192848841349285 0.6666666666666666 None
# Con cuda
# [test] Epoch 19/30. Iteration 0/1. Loss: 1.00. Accuracy: 0.67					 0.9986370205879211 0.6666666666666666 None
# [test] Epoch 19/30. Iteration 0/1. Loss: 3.00. Accuracy: 2.00
# Con cuda
# [train] Epoch 20/30. Iteration 0/2. Loss: 0.95. Accuracy: 0.75					 0.9462001323699951 0.75 None
# Con cuda
# [train] Epoch 20/30. Iteration 1/2. Loss: 0.96. Accuracy: 0.67					 0.9643452564875284 0.6666666666666666 None
# Con cuda
# [test] Epoch 20/30. Iteration 0/1. Loss: 0.91. Accuracy: 0.67					 0.9115781188011169 0.6666666666666666 None
# [test] Epoch 20/30. Iteration 0/1. Loss: 2.73. Accuracy: 2.00
# Con cuda
# [train] Epoch 21/30. Iteration 0/2. Loss: 0.79. Accuracy: 0.75					 0.7874876856803894 0.75 None
# Con cuda
# [train] Epoch 21/30. Iteration 1/2. Loss: 0.95. Accuracy: 0.50					 0.9491026004155477 0.5 None
# Con cuda
# [test] Epoch 21/30. Iteration 0/1. Loss: 0.80. Accuracy: 0.67					 0.8045980334281921 0.6666666666666666 None
# [test] Epoch 21/30. Iteration 0/1. Loss: 2.41. Accuracy: 2.00
# Con cuda
# [train] Epoch 22/30. Iteration 0/2. Loss: 0.60. Accuracy: 1.00					 0.5958366394042969 1.0 None
# Con cuda
# [train] Epoch 22/30. Iteration 1/2. Loss: 1.07. Accuracy: 0.83					 1.0745511054992676 0.8333333333333334 None
# Con cuda
# [test] Epoch 22/30. Iteration 0/1. Loss: 0.83. Accuracy: 0.33					 0.8287718892097473 0.3333333333333333 None
# [test] Epoch 22/30. Iteration 0/1. Loss: 2.49. Accuracy: 1.00
# Con cuda
# [train] Epoch 23/30. Iteration 0/2. Loss: 0.49. Accuracy: 1.00					 0.4902905523777008 1.0 None
# Con cuda
# [train] Epoch 23/30. Iteration 1/2. Loss: 0.62. Accuracy: 1.00					 0.6230035026868185 1.0 None
# Con cuda
# [test] Epoch 23/30. Iteration 0/1. Loss: 0.95. Accuracy: 0.67					 0.9451953768730164 0.6666666666666666 None
# [test] Epoch 23/30. Iteration 0/1. Loss: 2.84. Accuracy: 2.00
# Con cuda
# [train] Epoch 24/30. Iteration 0/2. Loss: 0.84. Accuracy: 0.75					 0.8411604762077332 0.75 None
# Con cuda
# [train] Epoch 24/30. Iteration 1/2. Loss: 0.88. Accuracy: 0.67					 0.8824683030446371 0.6666666666666666 None
# Con cuda
# [test] Epoch 24/30. Iteration 0/1. Loss: 0.86. Accuracy: 0.67					 0.8640968799591064 0.6666666666666666 None
# [test] Epoch 24/30. Iteration 0/1. Loss: 2.59. Accuracy: 2.00
# Con cuda
# [train] Epoch 25/30. Iteration 0/2. Loss: 0.86. Accuracy: 0.75					 0.8554123640060425 0.75 None
# Con cuda
# [train] Epoch 25/30. Iteration 1/2. Loss: 0.90. Accuracy: 0.67					 0.9035754799842834 0.6666666666666666 None
# Con cuda
# [test] Epoch 25/30. Iteration 0/1. Loss: 0.95. Accuracy: 0.67					 0.9513242840766907 0.6666666666666666 None
# [test] Epoch 25/30. Iteration 0/1. Loss: 2.85. Accuracy: 2.00
# Con cuda
# [train] Epoch 26/30. Iteration 0/2. Loss: 0.98. Accuracy: 0.50					 0.9760947227478027 0.5 None
# Con cuda
# [train] Epoch 26/30. Iteration 1/2. Loss: 0.90. Accuracy: 0.67					 0.9039268493652344 0.6666666666666666 None
# Con cuda
# [test] Epoch 26/30. Iteration 0/1. Loss: 0.68. Accuracy: 0.67					 0.684877872467041 0.6666666666666666 None
# [test] Epoch 26/30. Iteration 0/1. Loss: 2.05. Accuracy: 2.00
# Con cuda
# [train] Epoch 27/30. Iteration 0/2. Loss: 0.75. Accuracy: 0.50					 0.7518628835678101 0.5 None
# Con cuda
# [train] Epoch 27/30. Iteration 1/2. Loss: 0.60. Accuracy: 0.67					 0.6011854211489359 0.6666666666666666 None
# Con cuda
# [test] Epoch 27/30. Iteration 0/1. Loss: 0.81. Accuracy: 0.67					 0.8114712238311768 0.6666666666666666 None
# [test] Epoch 27/30. Iteration 0/1. Loss: 2.43. Accuracy: 2.00
# Con cuda
# [train] Epoch 28/30. Iteration 0/2. Loss: 0.12. Accuracy: 1.00					 0.11688989400863647 1.0 None
# Con cuda
# [train] Epoch 28/30. Iteration 1/2. Loss: 1.31. Accuracy: 0.67					 1.3050976991653442 0.6666666666666666 None
# Con cuda
# [test] Epoch 28/30. Iteration 0/1. Loss: 1.07. Accuracy: 0.67					 1.0707226991653442 0.6666666666666666 None
# [test] Epoch 28/30. Iteration 0/1. Loss: 3.21. Accuracy: 2.00
# Con cuda
# [train] Epoch 29/30. Iteration 0/2. Loss: 0.79. Accuracy: 0.75					 0.7885253429412842 0.75 None
# Con cuda
# [train] Epoch 29/30. Iteration 1/2. Loss: 0.94. Accuracy: 0.50					 0.9379988114039103 0.5 None
# Con cuda
# [test] Epoch 29/30. Iteration 0/1. Loss: 1.12. Accuracy: 0.33					 1.1227021217346191 0.3333333333333333 None
# [test] Epoch 29/30. Iteration 0/1. Loss: 3.37. Accuracy: 1.00
# Con cuda
# [train] Epoch 30/30. Iteration 0/2. Loss: 1.09. Accuracy: 0.25					 1.0896897315979004 0.25 None
# Con cuda
# [train] Epoch 30/30. Iteration 1/2. Loss: 1.12. Accuracy: 0.33					 1.1222113370895386 0.3333333333333333 None
# Con cuda
# [test] Epoch 30/30. Iteration 0/1. Loss: 1.13. Accuracy: 0.33					 1.1303714513778687 0.3333333333333333 None
# [test] Epoch 30/30. Iteration 0/1. Loss: 3.39. Accuracy: 1.00
# Ho finito.

# %%
from matplotlib import pyplot as plt
def plot_logs_classification(logs):
    training_losses, training_accuracies, test_losses, test_accuracies = \
    logs[0]['train'], logs[1]['train'], logs[0]['test'], logs[1]['test']
    plt.figure(figsize=(18,6))
    plt.subplot(121)
    plt.plot(training_losses)
    plt.plot(test_losses)
    plt.legend(['Training Loss','Test Losses'])
    plt.grid()
    plt.subplot(122)
    plt.plot(training_accuracies)
    plt.plot(test_accuracies)
    plt.legend(['Training Accuracy','Test Accuracy'])
    plt.grid()
    plt.show()

# %%
plot_logs_classification(lenet_mnist_logs)

# %%
import numpy as np
def test_model_classification(model, test_loader = mnist_test_loader):
    softmax = nn.Softmax(dim=1)
    model.eval()
    preds = []
    gts = []
    for batch in test_loader:
        x=Variable(batch["image"])
        #applichiamo la funzione softmax per avere delle probabilità
        if torch.cuda.is_available():
            x = x.cuda()
        pred = softmax(model(x)).data.cpu().numpy().copy()
        gt = batch["label"].cpu().numpy().copy()
        print("Pred-->", pred, ", gt-->", gt)
        preds.append(pred)
        gts.append(gt)
        #print(len(preds), len(gts))
    return np.concatenate(preds),np.concatenate(gts)

# %%
lenet_mnist_predictions, lenet_mnist_gt = test_model_classification(net)
print ("Accuracy LeNet su DIGITS: %0.2f" % \
accuracy_score(lenet_mnist_gt,lenet_mnist_predictions.argmax(1)))
# Out:
# Pred--> [[0.43793386 0.21056001 0.35150614]
#  [0.44440323 0.20931631 0.3462804 ]
#  [0.4170283  0.21565035 0.36732134]] , gt--> [0 1 2]
# Accuracy LeNet su DIGITS: 0.33
